# %%
import pandas as pd
re=pd.read_csv("s1.csv")

# %%
re.tail()
# Out:
#     Unnamed: 0                                     beautyproducts   price  \
# 35          35  MCaffeine Complete Winter Skincare Pack | Exfo...  ₹2,230
# 36          36  Rose Leaf Make up Kit combo of 9 – (High cover...    ₹389
# 37          37  Vedy HIGHLIGHTER AND CONTOUR STICK HIGHLIGHTER...    ₹469
# 38          38  GOLD MAX MAKEUP 3D BALM STICK WITH ALL GLAMORO...    ₹646
# 39          39  Skinkraft Face Wash - Face Moisturizer Combo -...    ₹221
#
#     Rating:
# 35      5.0
# 36      4.3
# 37      5.0
# 38      5.0
# 39      3.2

# %%
re.head()
# Out:
#    Unnamed: 0                                     beautyproducts   price  \
# 0           0  Rose Leaf Make up Kit - High coverage foundati...    ₹315
# 1           1  Rose Leaf Make up Kit combo of 14 - (Makeup fi...    ₹439
# 2           2  Rose Leaf Make up Kit combo of 13 – (Nude eye ...    ₹539
# 3           3  MCaffeine Must-Have Coffee Winter Skincare Set...  ₹1,510
# 4           4  Rose Leaf Makeup Combo kit Set of 11, foundati...    ₹289
#
#    Rating:
# 0      3.8
# 1      3.8
# 2      4.0
# 3      4.4
# 4      3.9

# %%
re.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 40 entries, 0 to 39
# Data columns (total 4 columns):
#  #   Column          Non-Null Count  Dtype
# ---  ------          --------------  -----
#  0   Unnamed: 0      40 non-null     int64
#  1   beautyproducts  40 non-null     object
#  2   price           40 non-null     object
#  3   Rating:         40 non-null     float64
# dtypes: float64(1), int64(1), object(2)
# memory usage: 1.4+ KB

# %%
import matplotlib.pyplot as plt
# %matplotlib inline
plt.bar(re["price"],re["beautyproducts"],width=0.5)
plt.figure(figsize=(3,6))
plt.show()

# %%
plt.bar(re["Rating:"],re["beautyproducts"],width=0.4)
plt.figure(figsize=(18,16))
plt.show()
